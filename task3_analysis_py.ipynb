# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradeep1694/trendpulse-Pradeep/blob/main/task3_analysis_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


df = pd.read_csv("data/trends_clean.csv")

print("Loaded data:", df.shape)

print("\nFirst 5 rows:")
print(df.head())


avg_score = df["score"].mean()
avg_comments = df["num_comments"].mean()

print("\nAverage score :", round(avg_score))
print("Average comments:", round(avg_comments))



scores = df["score"].values

print("\n--- NumPy Stats ---")
print("Mean score :", int(np.mean(scores)))
print("Median score :", int(np.median(scores)))
print("Std deviation:", int(np.std(scores)))
print("Max score :", int(np.max(scores)))
print("Min score :", int(np.min(scores)))



most_category = df["category"].value_counts().idxmax()
count_category = df["category"].value_counts().max()

print("\nMost stories in:", most_category, f"({count_category} stories)")



max_comments_idx = df["num_comments"].idxmax()
title = df.loc[max_comments_idx, "title"]
comments = df.loc[max_comments_idx, "num_comments"]

print('\nMost commented story:', f'"{title}" — {comments} comments')



df["engagement"] = df["num_comments"] / (df["score"] + 1)
df["is_popular"] = df["score"] > avg_score



df.to_csv("data/trends_analysed.csv", index=False)

print("\nFile saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2094/1616316796.py in <cell line: 0>()
#       3
#       4
# ----> 5 df = pd.read_csv("data/trends_clean.csv")
#       6
#       7 print("Loaded data:", df.shape)
#
# ...
